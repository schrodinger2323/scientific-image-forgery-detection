# %% [markdown]
# # Recod.ai/LUC - Deney 5 Calibration ve Post-processing
#
# Bu notebook, ayni klasordeki `recod_luc_experiment5_calibration_postprocessing.py` dosyasini calistirir. Ana kod dosyasi `# %%` hucre isaretleriyle notebook-style hazirlanmistir; VS Code/Jupyter'da hucreli olarak acilabilir, Kaggle/Colab'da ise bu notebook uzerinden tek seferde kosulabilir.
#
# Test seti threshold veya post-processing secimi icin kullanilmaz; secimler validation grid search ile yapilir.

# %% [markdown]
# ## 1. Install / Imports - 17. Report Generation
#
# Tum hucreler ve fonksiyonlar script dosyasindadir. Kaggle/Colab'a iki dosyayi birlikte yukleyip asagidaki hucreyi calistirin.

# %%
# %run recod_luc_experiment5_calibration_postprocessing.py
